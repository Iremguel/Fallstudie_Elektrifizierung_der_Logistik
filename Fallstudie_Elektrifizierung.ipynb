# %% [markdown]
# <a href="https://colab.research.google.com/github/Iremguel/Fallstudie_Elektrifizierung_der_Logistik/blob/main/Fallstudie_Elektrifizierung.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fallstudie Elektrifizierung

# %%
! pip install -q pyscipopt
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.2/17.2 MB 18.3 MB/s eta 0:00:00

# %%
import pandas as pd
from pyscipopt import Model, quicksum

# %%
! git clone https://github.com/Iremguel/Fallstudie_Elektrifizierung_der_Logistik.git
# Out:
# Cloning into 'Fallstudie_Elektrifizierung_der_Logistik'...
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 10 (delta 0), reused 7 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (10/10), done.

# %%
! ls
# Out:
# Fallstudie_Elektrifizierung_der_Logistik  sample_data

# %%
! ls Fallstudie_Elektrifizierung_der_Logistik/Daten/
# Out:
# chargers.csv  diesel_trucks.csv  electric_trucks.csv  routes.csv

# %%
folder = "Fallstudie_Elektrifizierung_der_Logistik/Daten/"

# %%
chargers = pd.read_csv(f"{folder}chargers.csv", sep=";")

# %%
diesel_trucks = pd.read_csv(f"{folder}/diesel_trucks.csv", sep=";")

# %%
electric_trucks = pd.read_csv(f"{folder}/electric_trucks.csv", sep=";")

# %%
routes = pd.read_csv(f"{folder}/routes.csv", sep=";")

# %%
electric_trucks
# Out:
#   truck_model  capex_yearly  opex_yearly  avg_energy_kWh_per_100km  \
# 0  eActros600         60000         6000                       110
# 1  eActros400         50000         5000                       105
#
#    thg_yearly  max_power  soc_max_kWh
# 0        1000        400          621
# 1        1000        400          414

# %% [markdown]
# ## Indexmengen

# %%
R = list(routes.route_name.unique())
# T = 15 min slots
D = list(diesel_trucks.truck_model.unique())
E = list(electric_trucks.truck_model.unique())

# %%
E
# Out:
# ['eActros600', 'eActros400']

# %% [markdown]
# ## Parameter

# %% [markdown]
# ## Entscheidungsvariablen

# %% [markdown]
# ## Zielfunktion

# %% [markdown]
# ## Nebenbedingungen

# %% [markdown]
# ## Lösung
